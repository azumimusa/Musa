# %%
workbook = xlrd.open_workbook(r'C:\Users\user\Desktop\UFOs_coord.xlsx')
sheet = workbook.sheet_by_index(0)
for rowx in range(sheet.nrows):
    values = sheet.row_values(rowx)
    print(values)
# Out:
# ['Date / Time', 'Country', 'City', 'State', 'Shape', 'Summary', 'lat', 'lng']
# ['12/21/16 19:15', 'USA', 'Waynesboro', 'VA', 'Sphere', 'Bright round object hovering in sky.', 38.0652286, -78.9058875592407]
# ['12/21/16 00:00', 'USA', 'Louisville', 'KY', 'Unknown', 'Multiple craft ascending from north of Shelbyville road, very bright and \nvery quiet in comparison to passenger planes seen in the sky a', 38.2542376, -85.7594069]
# ['12/20/16 22:30', 'USA', 'Santa Rosa', 'CA', 'Sphere', 'Bright orange planet-like object sighted near Cassiopia', 38.4404675, -122.7144313]
# ['12/20/16 19:00', 'USA', 'Fresno', 'CA', 'Circle', 'Twelve orange globes in formation over Fresno', 36.7295295, -119.708861160756]
# ['12/19/16 21:53', 'USA', 'Reymert', 'AZ', 'Circle', 'While camping in the Cottonwood canyon Rd., along the gas line rd., I awoke \nto my dog growling and staring north. I looked to see what', 33.2297793, -111.2092898]
# ...

# %%
sheet_count = workbook.nsheets
print('number of sheets: {0}'.format(sheet_count))
# Out:
# number of sheets 1

# %%
sheet_name = workbook.sheet_names()
print('sheet names is: {0}'.format(sheet_name))
# Out:
# sheet names is: ['Sheet1']

# %%
dir(sheet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cell_attr_to_xfx',
#  '_cell_types',
#  '_cell_values',
#  '_cell_xf_indexes',
#  '_dimncols',
#  '_dimnrows',
#  '_first_full_rowx',
#  '_ixfe',
#  '_maxdatacolx',
#  '_maxdatarowx',
#  '_position',
#  '_repr_these',
#  '_xf_index_stats',
#  '_xf_index_to_xl_type_map',
#  'automatic_grid_line_colour',
#  'bf',
#  'biff_version',
#  'book',
#  'bt',
#  'cached_normal_view_mag_factor',
#  'cached_page_break_preview_mag_factor',
#  'cell',
#  'cell_note_map',
#  'cell_type',
#  'cell_value',
#  'cell_xf_index',
#  'col',
#  'col_label_ranges',
#  'col_slice',
# ...

# %%
sheet_rows = sheet.nrows
sheet_columns= sheet.ncols
print('the rows: {0}, and columns {1}'.format(sheet_rows, sheet_columns))
# Out:
# the rows: 5178, and columns 8

# %%
table = list()
record = list()

for x in range(sheet_rows):
    for y in range(sheet_columns):
        record.append(sheet.cell(x,y))
    table.append(record)
    record = []
    x+=1
print(table)
# Out:
# [[text:'Date / Time', text:'Country', text:'City', text:'State', text:'Shape', text:'Summary', text:'lat', text:'lng'], [text:'12/21/16 19:15', text:'USA', text:'Waynesboro', text:'VA', text:'Sphere', text:'Bright round object hovering in sky.', number:38.0652286, number:-78.9058875592407], [text:'12/21/16 00:00', text:'USA', text:'Louisville', text:'KY', text:'Unknown', text:'Multiple craft ascending from north of Shelbyville road, very bright and \nvery quiet in comparison to passenger planes seen in the sky a', number:38.2542376, number:-85.7594069], [text:'12/20/16 22:30', text:'USA', text:'Santa Rosa', text:'CA', text:'Sphere', text:'Bright orange planet-like object sighted near Cassiopia', number:38.4404675, number:-122.7144313], [text:'12/20/16 19:00', text:'USA', text:'Fresno', text:'CA', text:'Circle', text:'Twelve orange globes in formation over Fresno', number:36.7295295, number:-119.708861160756], [text:'12/19/16 21:53', text:'USA', text:'Reymert', text:'AZ', text:'Circle
# ...

# %%
import pandas as pd
def convert_any_cell(cell):
    if cell=='n.a.':
        return 'Musa'
    return cell
def converter_any_cell(cell):
    if cell=='not available':
        return None
    return cell
df= pd.read_excel(r'C:\Users\user\Desktop\UFOs_coord.xlsx', 'Sheet1', converters = {'Country': convert_any_cell})
df
# Out:
#               Date / Time Country        City State     Shape  \
# 0          12/21/16 19:15     USA  Waynesboro    VA    Sphere
# 1          12/21/16 00:00     USA  Louisville    KY   Unknown
# 2          12/20/16 22:30     USA  Santa Rosa    CA    Sphere
# 3          12/20/16 19:00     USA      Fresno    CA    Circle
# 4          12/19/16 21:53     USA     Reymert    AZ    Circle
# ...                   ...     ...         ...   ...       ...
# 5172  2016-01-01 00:00:00     USA   Elk Grove    CA     Light
# 5173  2016-01-01 00:00:00     USA   Anchorage    AK    Circle
# 5174  2016-01-01 00:00:00     USA   Sodaville    OR    Sphere
# 5175  2016-01-01 00:00:00     USA      Arnold    MO  Triangle
# 5176  2016-01-01 00:00:00     USA      Vernon    CT    Sphere
#
#                                                 Summary        lat         lng
# 0                  Bright round object hovering in sky.  38.065229  -78.905888
# ...

# %%
df.isnull().sum()
# Out:
# Date / Time    0
# Country        0
# City           0
# State          0
# Shape          0
# Summary        0
# lat            0
# lng            0
# dtype: int64

# %%
df.shape
# Out:
# (5177, 8)

# %%
df.to_excel('new.xlsx', sheet_name='Cuneo', startrow=1, startcol=2, index=False)
